# %% [markdown]
# <a href="https://colab.research.google.com/github/son50git/Routine-with-Python/blob/master/GB_Rolling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive, files
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a5256692-5274-4d27-a8d3-b97b9115a72a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5256692-5274-4d27-a8d3-b97b9115a72a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Routine_rpts_20201121_1803.xlsx to Routine_rpts_20201121_1803.xlsx

# %%
woe_df = pd.read_excel('Routine_rpts_20201121_1803.xlsx', sheet_name='Efficiency--Adjusted')  
woe_df = woe.reset_index().set_index(["Date"])
woe_df["good_rolling"] = woe_df.G_0.rolling(3, min_periods=3).mean()
woe_df["bad_rolling"] = woe_df.B_0.rolling(3, min_periods=3).mean()
woe_df
# Out:
#             index  Day  G_0  ...  group_score  good_rolling  bad_rolling
# Date                         ...
# 09/29/2020      0  TUE  496  ...     0.152285           NaN          NaN
# 09/30/2020      1  WED  531  ...     0.118798           NaN          NaN
# 10/01/2020      2  THU  397  ...     0.098740    474.666667   494.000000
# 10/02/2020      3  FRI  607  ...     0.154032    511.666667   382.333333
# 10/03/2020      4  SAT  566  ...     0.147606    523.333333   340.333333
# 10/04/2020      5  SUN  528  ...     0.179748    567.000000   345.666667
# 10/05/2020      6  MON  323  ...     0.173094    472.333333   443.333333
# 10/06/2020      7  TUE  357  ...     0.115715    402.666667   469.333333
# 10/07/2020      8  WED  467  ...     0.080782    382.333333   473.000000
# 10/08/2020      9  THU  220  ...     0.070293    348.000000   393.333333
# 10/09/2020     10  FRI  439  ...     0.034349    375.333333   338.333333
# ...
